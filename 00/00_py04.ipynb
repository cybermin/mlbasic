# %% [markdown]
# # 한글 폰트 추가

# %%
#시각화 모듈
import matplotlib.pyplot as plt
# 폰트 적용
plt.rcParams['font.family'] = 'Malgun Gothic'
# unicode minus를 사용하지 않기 위한 설정 (minus 깨짐현상 방지)
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# # 판다스(pandas)
# + 파이썬에서 사용하는 데이터분석 라이브러리
#
# + 행과 열로 이루어진 데이터 객체를 만들어 다룰 수 있게 되며 보다 안정적으로 대용량의 데이터들을 처리하는데 매우 편리한 도구
#
# + NumPy를 기반으로 구축되었으며 과학 컴퓨팅 환경 내에서 다른 많은 타사 라이브러리와 잘 통합되도록 설계

# %%
import pandas as pd

# %% [markdown]
# ## 외부데이터 가져오기
# + csv 읽기
#  - 한글 파일명을 사용할 경우 : df = pd.read_csv(‘파일명‘, engine='python')
#  - 파일 내용 한글이 깨지는 경우 : df = pd.read_csv(‘파일명‘, engine='python', encoding='cp949')
#
# ```
# df = pd.read_csv(‘파일명‘)
# ```
#
# + 엑셀 읽기
#  - 한글 파일명을 사용할 경우 : df = pd.read_excel(‘파일명‘)
#
# ```
# df = pd.read_excel(‘파일명‘)
# ```

# %%
dfe = pd.read_excel('C:/Users/user/work/sidoAirInfo12.xls')

# %%
dfe
# Out:
#             날짜   서울  부산  대구  인천  광주  대전  울산   경기  강원  충북  충남  전북  전남  경북  경남  \
# 0   2020-12-31   26  15  19  26  19  28  14   29  23  27  29  20  14  20  12
# 1   2020-12-30   33  19  21  26  13  24  19   33  30  27  28  17  16  26  14
# 2   2020-12-29   65  44  60  64  37  58  41   68  48  65  65  46  31  52  35
# 3   2020-12-28   61  35  58  56  23  48  34   69  48  62  60  33  23  49  28
# 4   2020-12-27   63  38  58  55  38  52  42   69  58  65  53  43  34  59  40
# 5   2020-12-26   55  36  47  59  38  40  40   60  45  44  51  37  32  43  35
# 6   2020-12-25   27  25  26  26  21  28  22   29  23  25  30  25  21  26  21
# 7   2020-12-24   61  56  67  54  66  55  51   64  55  64  65  59  54  59  54
# 8   2020-12-23   67  65  76  60  78  66  56   74  68  77  71  66  63  64  61
# 9   2020-12-22   50  47  54  49  53  46  44   56  46  61  52  49  45  45  43
# 10  2020-12-21   39  36  40  37  38  36  28   44  27  42  44  38  30  33  33
# ...

# %%
df = pd.read_csv("C:/Users/user/work/sidoAirInfo3_pd.csv", encoding="cp949")

# %%
df
# Out:
#             날짜  서울  부산  대구  인천  광주    대전  울산  경기  강원  충북  충남  전북  전남  경북  경남  \
# 0   2020-08-01  15  23  26  17  16  17.0  26  17  17  20  19  16  21  20  24
# 1   2020-08-02  12  41  28  15  18  13.0  33  12  11  14  17  17  31  25  36
# 2   2020-08-03  15  44  32  19  29  18.0  36  14  12  18  23  26  38  28  40
# 3   2020-08-04  38  65  44  47  38  25.0  54  35  16  23  38  34  52  38  57
# 4   2020-08-05  35  34  41  36  28  28.0  33  33  16  23  32  28  33  39  34
# 5   2020-08-06  16  43  23  16  20   NaN  30  16  12  14  18  18  25  22  32
# 6   2020-08-07  27  48  18  22  16   6.0  37  27  21  17  19  13  46  17  42
# 7   2020-08-08  14  16   7  13  12   5.0  14  15  14  12  12   8  21   8  15
# 8   2020-08-09  10  17  11  11  11   9.0  13  11  11  12  13  11  17  14  15
# 9   2020-08-10  13  15   9  13   8   8.0  15  13  12  11  12   8  13   9  12
# 10  2020-08-11  11  23  22  11  20  11.0  19  13  10  10  16  18  23  17  20
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 18 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      31 non-null     object
#  1   서울      31 non-null     int64
#  2   부산      31 non-null     int64
#  3   대구      31 non-null     int64
#  4   인천      31 non-null     int64
#  5   광주      31 non-null     int64
#  6   대전      30 non-null     float64
#  7   울산      31 non-null     int64
#  8   경기      31 non-null     int64
#  9   강원      31 non-null     int64
#  10  충북      31 non-null     int64
#  11  충남      31 non-null     int64
#  12  전북      31 non-null     int64
#  13  전남      31 non-null     int64
#  14  경북      31 non-null     int64
#  15  경남      31 non-null     int64
#  16  제주      30 non-null     float64
#  17  세종      31 non-null     int64
# dtypes: float64(2), int64(15), object(1)
# memory usage: 4.5+ KB

# %%
df
# Out:
#             날짜  서울  부산  대구  인천  광주    대전  울산  ...  충북  충남  전북  전남  경북  경남    제주  세종
# 0   2020-08-01  15  23  26  17  16  17.0  26  ...  20  19  16  21  20  24  28.0  17
# 1   2020-08-02  12  41  28  15  18  13.0  33  ...  14  17  17  31  25  36  38.0  14
# 2   2020-08-03  15  44  32  19  29  18.0  36  ...  18  23  26  38  28  40  42.0  18
# 3   2020-08-04  38  65  44  47  38  25.0  54  ...  23  38  34  52  38  57  54.0  26
# 4   2020-08-05  35  34  41  36  28  28.0  33  ...  23  32  28  33  39  34  32.0  26
# 5   2020-08-06  16  43  23  16  20   NaN  30  ...  14  18  18  25  22  32  42.0  14
# 6   2020-08-07  27  48  18  22  16   6.0  37  ...  17  19  13  46  17  42  62.0  15
# 7   2020-08-08  14  16   7  13  12   5.0  14  ...  12  12   8  21   8  15  24.0   6
# 8   2020-08-09  10  17  11  11  11   9.0  13  ...  12  13  11  17  14  15  17.0  10
# 9   2020-08-10  13  15   9  13   8   8.0  15  ...  11  12   8  13   9  12  19.0  10
# ...

# %% [markdown]
# ## Series
#
# + index로 value를 구분하는 1차원 자료구조

# %%
dsbusan = df['부산']
dsbusan
# Out:
# 0     23
# 1     41
# 2     44
# 3     65
# 4     34
# 5     43
# 6     48
# 7     16
# 8     17
# 9     15
# 10    23
# 11    20
# 12    23
# 13    25
# 14    29
# 15    21
# 16    35
# 17    47
# 18    54
# 19    53
# 20    44
# 21    24
# 22    28
# 23    30
# 24    38
# 25    28
# 26    21
# 27    14
# 28    14
# 29    23
# 30    16
# Name: 부산, dtype: int64

# %%
type(dsbusan)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### 인덱스와 값 추출

# %%
#인덱스 
print(dsbusan.index)
print(dsbusan.keys())
# Out:
# RangeIndex(start=0, stop=31, step=1)
# RangeIndex(start=0, stop=31, step=1)

# %%
#값 추출
print(dsbusan.values)
# Out:
# [23 41 44 65 34 43 48 16 17 15 23 20 23 25 29 21 35 47 54 53 44 24 28 30
#  38 28 21 14 14 23 16]

# %%
dsbusan[20:25]
# Out:
# 20    44
# 21    24
# 22    28
# 23    30
# 24    38
# Name: 부산, dtype: int64

# %% [markdown]
# ### 인덱스로 시리즈 데이터 가져오기

# %%
print(dsbusan[2])
# Out:
# 44

# %%
print(dsbusan[2:5])
# Out:
# 2    44
# 3    65
# 4    34
# Name: 부산, dtype: int64

# %%
print(dsbusan[[2,5]])
# Out:
# 2    44
# 5    43
# Name: 부산, dtype: int64

# %%
print(dsbusan[:2])
# Out:
# 0    23
# 1    41
# Name: 부산, dtype: int64

# %%
print(dsbusan[28:])
# Out:
# 28    14
# 29    23
# 30    16
# Name: 부산, dtype: int64

# %% [markdown]
# ### 조건에 맞는 자료 가져오기

# %%
print(dsbusan[dsbusan.index > 25])
# Out:
# 26    21
# 27    14
# 28    14
# 29    23
# 30    16
# Name: 부산, dtype: int64

# %%
print(dsbusan[dsbusan.values > 25])
# Out:
# 1     41
# 2     44
# 3     65
# 4     34
# 5     43
# 6     48
# 14    29
# 16    35
# 17    47
# 18    54
# 19    53
# 20    44
# 22    28
# 23    30
# 24    38
# 25    28
# Name: 부산, dtype: int64

# %% [markdown]
# ### 시리즈(series) 인덱스 변경하기

# %%
dsbusan.index
# Out:
# RangeIndex(start=0, stop=31, step=1)

# %%
dsbusan.index = df['날짜']
dsbusan
# Out:
# 날짜
# 2020-08-01    23
# 2020-08-02    41
# 2020-08-03    44
# 2020-08-04    65
# 2020-08-05    34
# 2020-08-06    43
# 2020-08-07    48
# 2020-08-08    16
# 2020-08-09    17
# 2020-08-10    15
# 2020-08-11    23
# 2020-08-12    20
# 2020-08-13    23
# 2020-08-14    25
# 2020-08-15    29
# 2020-08-16    21
# 2020-08-17    35
# 2020-08-18    47
# 2020-08-19    54
# 2020-08-20    53
# 2020-08-21    44
# 2020-08-22    24
# 2020-08-23    28
# 2020-08-24    30
# 2020-08-25    38
# 2020-08-26    28
# 2020-08-27    21
# 2020-08-28    14
# 2020-08-29    14
# 2020-08-30    23
# 2020-08-31    16
# Name: 부산, dtype: int64

# %%
dsbusan[dsbusan.index >= '2020-08-30']
# Out:
# 날짜
# 2020-08-30    23
# 2020-08-31    16
# Name: 부산, dtype: int64

# %%
print(dsbusan[dsbusan.values > 50])
# Out:
# 날짜
# 2020-08-04    65
# 2020-08-19    54
# 2020-08-20    53
# Name: 부산, dtype: int64

# %%
print([dsbusan.values > 50])
print(dsbusan[dsbusan.values > 50])
# Out:
# [array([False, False, False,  True, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#         True,  True, False, False, False, False, False, False, False,
#        False, False, False, False])]
# 날짜
# 2020-08-04    65
# 2020-08-19    54
# 2020-08-20    53
# Name: 부산, dtype: int64

# %% [markdown]
# ### 시각화

# %%
dsbusan.plot()
plt.xticks(rotation=90)
plt.title('부산 미세먼지')
plt.show()

# %% [markdown]
# ### series 기초 통계
# *   mean() : 평균
# *   max() : 최대
# *   min() : 최소
# *   std() : 표준편차
# *   describe() : 요약 통계량 계산

# %%
print(f'평균 : {dsbusan.mean():0.2f}')
print(f'최대 : {dsbusan.max():0.2f}')
print(f'최소 : {dsbusan.min():0.2f}')
print(f'표준편차 : {dsbusan.std():0.2f}')
print(f'요약 \n{dsbusan.describe() }')
# Out:
# 평균 : 30.84
# 최대 : 65.00
# 최소 : 14.00
# 표준편차 : 13.58
# 요약
# count    31.000000
# mean     30.838710
# std      13.582088
# min      14.000000
# 25%      21.000000
# 50%      28.000000
# 75%      42.000000
# max      65.000000
# Name: 부산, dtype: float64

# %%
dsup = dsbusan[dsbusan>dsbusan.mean()]
dsup
# Out:
# 날짜
# 2020-08-02    41
# 2020-08-03    44
# 2020-08-04    65
# 2020-08-05    34
# 2020-08-06    43
# 2020-08-07    48
# 2020-08-17    35
# 2020-08-18    47
# 2020-08-19    54
# 2020-08-20    53
# 2020-08-21    44
# 2020-08-25    38
# Name: 부산, dtype: int64

# %% [markdown]
# ### series 자주사용되는 메소드
# * replace() : 특정값을 가진 요소 값을 변경
# * equals() : 시리즈와 시리즈가 같은지 비교
# * isin() : 시리즈에 포함된 값이 있는지 확인
# * drop_duplicates() : 중복값이 없는 시리즈 반환
# * append() : 2개이상의 시리즈 연결
# * sort_index() : 인덱스로 정렬
#   + ascending = False : 역순 정렬 옵션
# * sort_values() : 값으로 정렬
# * to_frame() : 시리즈를 데이터프레임으로 변경

# %%
dsup.sort_values(ascending = False)
# Out:
# 날짜
# 2020-08-04    65
# 2020-08-19    54
# 2020-08-20    53
# 2020-08-07    48
# 2020-08-18    47
# 2020-08-21    44
# 2020-08-03    44
# 2020-08-06    43
# 2020-08-02    41
# 2020-08-25    38
# 2020-08-17    35
# 2020-08-05    34
# Name: 부산, dtype: int64

# %%
dsupdf = dsup.to_frame()
dsupdf
# Out:
#             부산
# 날짜
# 2020-08-02  41
# 2020-08-03  44
# 2020-08-04  65
# 2020-08-05  34
# 2020-08-06  43
# 2020-08-07  48
# 2020-08-17  35
# 2020-08-18  47
# 2020-08-19  54
# 2020-08-20  53
# 2020-08-21  44
# 2020-08-25  38

# %%
dsupdf = pd.DataFrame(dsup)
dsupdf
# Out:
#             부산
# 날짜
# 2020-08-02  41
# 2020-08-03  44
# 2020-08-04  65
# 2020-08-05  34
# 2020-08-06  43
# 2020-08-07  48
# 2020-08-17  35
# 2020-08-18  47
# 2020-08-19  54
# 2020-08-20  53
# 2020-08-21  44
# 2020-08-25  38

# %% [markdown]
# #### **시리즈 내에 유일한 값 확인**
# + .unique()
#  - 개별 컬럼 내에 유일한 값을 확인

# %%
dsup.unique()
# Out:
# array([41, 44, 65, 34, 43, 48, 35, 47, 54, 53, 38])

# %% [markdown]
# ### series 연산 (인덱스가 같은 것끼리 연산)
# + \+ : 같은 길이의 시리즈와 시리즈 더하기
# + \* : 같은 길이의 시리즈와 시리즈 곱하기

# %%
ds1 = dsbusan[dsbusan.index < '2020-08-05']
ds1
# Out:
# 날짜
# 2020-08-01    23
# 2020-08-02    41
# 2020-08-03    44
# 2020-08-04    65
# Name: 부산, dtype: int64

# %%
ds2 = dsbusan[dsbusan.index > '2020-08-27']
ds2
# Out:
# 날짜
# 2020-08-28    14
# 2020-08-29    14
# 2020-08-30    23
# 2020-08-31    16
# Name: 부산, dtype: int64

# %%
ds1 + ds2
# Out:
# 날짜
# 2020-08-01   NaN
# 2020-08-02   NaN
# 2020-08-03   NaN
# 2020-08-04   NaN
# 2020-08-28   NaN
# 2020-08-29   NaN
# 2020-08-30   NaN
# 2020-08-31   NaN
# Name: 부산, dtype: float64

# %%
ds1.index = range(4)
ds2.index = range(4)

# %%
print(ds1)
print(ds2)
# Out:
# 0    23
# 1    41
# 2    44
# 3    65
# Name: 부산, dtype: int64
# 0    14
# 1    14
# 2    23
# 3    16
# Name: 부산, dtype: int64

# %%
ds1 * ds2
# Out:
# 0     322
# 1     574
# 2    1012
# 3    1040
# Name: 부산, dtype: int64

# %% [markdown]
# ## 해결문제
# ---
# 해결문제)서울의 8월 20일이후의 미세먼지 변화량을 그래프로 작성하시오.
#
#
# ---

# %%
dsseoul = df['서울']
dsseoul[:5]
# Out:
# 0    15
# 1    12
# 2    15
# 3    38
# 4    35
# Name: 서울, dtype: int64

# %%
dsseoul.index = df['날짜']
dsseoul[:5]
# Out:
# 날짜
# 2020-08-01    15
# 2020-08-02    12
# 2020-08-03    15
# 2020-08-04    38
# 2020-08-05    35
# Name: 서울, dtype: int64

# %%
dsseoul = dsseoul[dsseoul.index>='2020-08-20']
dsseoul
# Out:
# 날짜
# 2020-08-20    37
# 2020-08-21    29
# 2020-08-22    17
# 2020-08-23    13
# 2020-08-24    24
# 2020-08-25    32
# 2020-08-26    23
# 2020-08-27    21
# 2020-08-28    23
# 2020-08-29    16
# 2020-08-30    14
# 2020-08-31    10
# Name: 서울, dtype: int64

# %%
dsseoul.plot(marker='o')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## DataFrame
# + 2차원 자료구조인 DataFrame는 행과 열이 있는 테이블 데이터
# + 딕션너리를 데이터 프레임으로 변경
#  - 딕션너리 키 : 열(column)
#  - 딕션너리 값 : 행(row)

# %%
df
# Out:
#             날짜  서울  부산  대구  인천  광주    대전  울산  ...  충북  충남  전북  전남  경북  경남    제주  세종
# 0   2020-08-01  15  23  26  17  16  17.0  26  ...  20  19  16  21  20  24  28.0  17
# 1   2020-08-02  12  41  28  15  18  13.0  33  ...  14  17  17  31  25  36  38.0  14
# 2   2020-08-03  15  44  32  19  29  18.0  36  ...  18  23  26  38  28  40  42.0  18
# 3   2020-08-04  38  65  44  47  38  25.0  54  ...  23  38  34  52  38  57  54.0  26
# 4   2020-08-05  35  34  41  36  28  28.0  33  ...  23  32  28  33  39  34  32.0  26
# 5   2020-08-06  16  43  23  16  20   NaN  30  ...  14  18  18  25  22  32  42.0  14
# 6   2020-08-07  27  48  18  22  16   6.0  37  ...  17  19  13  46  17  42  62.0  15
# 7   2020-08-08  14  16   7  13  12   5.0  14  ...  12  12   8  21   8  15  24.0   6
# 8   2020-08-09  10  17  11  11  11   9.0  13  ...  12  13  11  17  14  15  17.0  10
# 9   2020-08-10  13  15   9  13   8   8.0  15  ...  11  12   8  13   9  12  19.0  10
# ...

# %% [markdown]
# ### **N행 확인하기**
# + .head(N)
#   - 데이터프레임의 상위 N개의 행을 출력
#   - N생략하면 5개
# + .tail(N)
#  - 하위 N개의 행을 출력

# %%
df.head(2)
# Out:
#            날짜  서울  부산  대구  인천  광주    대전  울산  ...  충북  충남  전북  전남  경북  경남    제주  세종
# 0  2020-08-01  15  23  26  17  16  17.0  26  ...  20  19  16  21  20  24  28.0  17
# 1  2020-08-02  12  41  28  15  18  13.0  33  ...  14  17  17  31  25  36  38.0  14
#
# [2 rows x 18 columns]

# %%
df.tail(2)
# Out:
#             날짜  서울  부산  대구  인천  광주    대전  울산  ...  충북  충남  전북  전남  경북  경남    제주  세종
# 29  2020-08-30  14  23  17  15  12  11.0  17  ...  11  16  11  17  13  20  21.0  12
# 30  2020-08-31  10  16  14  11  18   7.0  15  ...  12  17  15  19  15  19  22.0  10
#
# [2 rows x 18 columns]

# %% [markdown]
# ### **정보 확인하기**
# + .shape 속성
#  - (행, 열) 크기를 확인하기
#  - 행의 개수 : len(데이터프레임), len(.index), .shape[0]
#  - 열의 개수 : len(.column), .shape[1]

# %%
df.shape
# Out:
# (31, 18)

# %%
#행의 개수
print(df.shape[0])
print(len(df))
print(len(df.index))
# Out:
# 31
# 31
# 31

# %%
df.columns
# Out:
# Index(['날짜', '서울', '부산', '대구', '인천', '광주', '대전', '울산', '경기', '강원', '충북', '충남',
#        '전북', '전남', '경북', '경남', '제주', '세종'],
#       dtype='object')

# %%
#열의 개수
print(df.shape[1]) 
print(len(df.columns))
# Out:
# 18
# 18

# %% [markdown]
# + .info()
#  - 데이터프레임에 대한 전반적인 정보
#  - 데이터프레임을 구성하는 행과 열의 크기, 컬럼명, 컬럼을 구성하는 값의 자료형 등을 출력

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 18 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      31 non-null     object
#  1   서울      31 non-null     int64
#  2   부산      31 non-null     int64
#  3   대구      31 non-null     int64
#  4   인천      31 non-null     int64
#  5   광주      31 non-null     int64
#  6   대전      30 non-null     float64
#  7   울산      31 non-null     int64
#  8   경기      31 non-null     int64
#  9   강원      31 non-null     int64
#  10  충북      31 non-null     int64
#  11  충남      31 non-null     int64
#  12  전북      31 non-null     int64
#  13  전남      31 non-null     int64
#  14  경북      31 non-null     int64
#  15  경남      31 non-null     int64
#  16  제주      30 non-null     float64
#  17  세종      31 non-null     int64
# dtypes: float64(2), int64(15), object(1)
# memory usage: 4.5+ KB

# %% [markdown]
# + .count()
#  - Null이 아닌 행의 개수 확인
#  - axis='columns' : Null이 아닌 열의 개수 확인

# %%
df.count()
# Out:
# 날짜    31
# 서울    31
# 부산    31
# 대구    31
# 인천    31
# 광주    31
# 대전    30
# 울산    31
# 경기    31
# 강원    31
# 충북    31
# 충남    31
# 전북    31
# 전남    31
# 경북    31
# 경남    31
# 제주    30
# 세종    31
# dtype: int64

# %%
df.count(axis='columns')
# Out:
# 0     18
# 1     18
# 2     18
# 3     18
# 4     18
# 5     17
# 6     18
# 7     18
# 8     18
# 9     18
# 10    18
# 11    18
# 12    18
# 13    18
# 14    18
# 15    18
# 16    18
# 17    18
# 18    18
# 19    18
# 20    18
# 21    18
# 22    18
# 23    18
# 24    18
# 25    17
# 26    18
# 27    18
# 28    18
# 29    18
# 30    18
# dtype: int64

# %%
df.count(axis=1)
# Out:
# 0     18
# 1     18
# 2     18
# 3     18
# 4     18
# 5     17
# 6     18
# 7     18
# 8     18
# 9     18
# 10    18
# 11    18
# 12    18
# 13    18
# 14    18
# 15    18
# 16    18
# 17    18
# 18    18
# 19    18
# 20    18
# 21    18
# 22    18
# 23    18
# 24    18
# 25    17
# 26    18
# 27    18
# 28    18
# 29    18
# 30    18
# dtype: int64

# %% [markdown]
# ### **값이 나온 횟수**
# + .value_counts()
#  - 개별 컬럼 내에 각각의 값이 나온 횟수
#  - normalize 옵션 : % 로도 표현

# %%
df['부산'].unique()
# Out:
# array([23, 41, 44, 65, 34, 43, 48, 16, 17, 15, 20, 25, 29, 21, 35, 47, 54,
#        53, 24, 28, 30, 38, 14])

# %%
df['부산'].value_counts().sort_index()
# Out:
# 14    2
# 15    1
# 16    2
# 17    1
# 20    1
# 21    2
# 23    4
# 24    1
# 25    1
# 28    2
# 29    1
# 30    1
# 34    1
# 35    1
# 38    1
# 41    1
# 43    1
# 44    2
# 47    1
# 48    1
# 53    1
# 54    1
# 65    1
# Name: 부산, dtype: int64

# %%
df['부산'].hist()

# %%
df['부산'].value_counts(normalize = True)
# Out:
# 23    0.129032
# 14    0.064516
# 28    0.064516
# 21    0.064516
# 16    0.064516
# 44    0.064516
# 30    0.032258
# 34    0.032258
# 35    0.032258
# 53    0.032258
# 47    0.032258
# 41    0.032258
# 43    0.032258
# 17    0.032258
# 15    0.032258
# 48    0.032258
# 29    0.032258
# 20    0.032258
# 54    0.032258
# 24    0.032258
# 25    0.032258
# 38    0.032258
# 65    0.032258
# Name: 부산, dtype: float64

# %% [markdown]
# ####**요약 통계량 확인**
# + .describe()
#  - 데이터프레임의 열별 요약 통계량
#  - sum(),mean(), max(), median()등 개별 함수를 사용가능

# %%
df.sum()
# Out:
# 날짜    2020-08-012020-08-022020-08-032020-08-042020-0...
# 서울                                                  709
# 부산                                                  956
# 대구                                                  790
# 인천                                                  735
# 광주                                                  673
# 대전                                                  593
# 울산                                                  870
# 경기                                                  741
# 강원                                                  585
# 충북                                                  662
# 충남                                                  749
# 전북                                                  670
# 전남                                                  844
# 경북                                                  717
# 경남                                                  897
# 제주                                                  871
# ...

# %%
df.mean()
# Out:
# 서울    22.870968
# 부산    30.838710
# 대구    25.483871
# 인천    23.709677
# 광주    21.709677
# 대전    19.766667
# 울산    28.064516
# 경기    23.903226
# 강원    18.870968
# 충북    21.354839
# 충남    24.161290
# 전북    21.612903
# 전남    27.225806
# 경북    23.129032
# 경남    28.935484
# 제주    29.033333
# 세종    20.322581
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 0     19.941176
# 1     22.058824
# 2     26.588235
# 3     40.235294
# 4     31.235294
# 5     22.562500
# 6     26.647059
# 7     12.705882
# 8     12.529412
# 9     11.764706
# 10    16.352941
# 11    20.411765
# 12    22.000000
# 13    26.588235
# 14    26.352941
# 15    20.294118
# 16    25.470588
# 17    32.705882
# 18    40.411765
# 19    38.117647
# 20    35.941176
# 21    27.588235
# 22    22.823529
# 23    28.647059
# 24    31.705882
# 25    23.500000
# 26    22.000000
# 27    18.764706
# 28    13.764706
# 29    15.117647
# 30    14.470588
# dtype: float64

# %%
df.describe()
# Out:
#               서울         부산         대구  ...         경남         제주         세종
# count  31.000000  31.000000  31.000000  ...  31.000000  30.000000  31.000000
# mean   22.870968  30.838710  25.483871  ...  28.935484  29.033333  20.322581
# std     9.590766  13.582088   9.956140  ...  11.093348  10.694773   8.852070
# min    10.000000  14.000000   7.000000  ...  12.000000  16.000000   6.000000
# 25%    14.500000  21.000000  19.500000  ...  20.500000  21.250000  14.000000
# 50%    23.000000  28.000000  25.000000  ...  27.000000  26.500000  19.000000
# 75%    30.500000  42.000000  31.500000  ...  35.500000  34.000000  26.000000
# max    43.000000  65.000000  48.000000  ...  57.000000  62.000000  40.000000
#
# [8 rows x 17 columns]

# %%
df.boxplot(figsize=(10,7))

# %% [markdown]
# ## **데이터프레임 슬라이싱**
# + .loc[행인덱싱, 열인덱싱]
# + .iloc[행순서번호, 열순서번호]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=31, step=1)

# %%
df.columns
# Out:
# Index(['날짜', '서울', '부산', '대구', '인천', '광주', '대전', '울산', '경기', '강원', '충북', '충남',
#        '전북', '전남', '경북', '경남', '제주', '세종'],
#       dtype='object')

# %% [markdown]
# #### **.loc : 인덱싱으로 추출**

# %%
df.columns
# Out:
# Index(['날짜', '서울', '부산', '대구', '인천', '광주', '대전', '울산', '경기', '강원', '충북', '충남',
#        '전북', '전남', '경북', '경남', '제주', '세종'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=31, step=1)

# %%
df.head()
# Out:
#            날짜  서울  부산  대구  인천  광주    대전  울산  ...  충북  충남  전북  전남  경북  경남    제주  세종
# 0  2020-08-01  15  23  26  17  16  17.0  26  ...  20  19  16  21  20  24  28.0  17
# 1  2020-08-02  12  41  28  15  18  13.0  33  ...  14  17  17  31  25  36  38.0  14
# 2  2020-08-03  15  44  32  19  29  18.0  36  ...  18  23  26  38  28  40  42.0  18
# 3  2020-08-04  38  65  44  47  38  25.0  54  ...  23  38  34  52  38  57  54.0  26
# 4  2020-08-05  35  34  41  36  28  28.0  33  ...  23  32  28  33  39  34  32.0  26
#
# [5 rows x 18 columns]

# %%
#행추출
df.loc[4, '부산']
# Out:
# 34

# %%
#행추출
df.loc[[2, 3, 4], ['부산']]
# Out:
#    부산
# 2  44
# 3  65
# 4  34

# %%
#열추출
df.loc[:,['부산','서울']]
# Out:
#     부산  서울
# 0   23  15
# 1   41  12
# 2   44  15
# 3   65  38
# 4   34  35
# 5   43  16
# 6   48  27
# 7   16  14
# 8   17  10
# 9   15  13
# 10  23  11
# 11  20  23
# 12  23  26
# 13  25  33
# 14  29  37
# 15  21  23
# 16  35  25
# 17  47  34
# 18  54  43
# 19  53  37
# 20  44  29
# 21  24  17
# 22  28  13
# 23  30  24
# 24  38  32
# 25  28  23
# 26  21  21
# 27  14  23
# 28  14  16
# 29  23  14
# 30  16  10

# %%
#열추출
df.loc[:,['부산','대구']]
# Out:
#     부산  대구
# 0   23  26
# 1   41  28
# 2   44  32
# 3   65  44
# 4   34  41
# 5   43  23
# 6   48  18
# 7   16   7
# 8   17  11
# 9   15   9
# 10  23  22
# 11  20  22
# 12  23  24
# 13  25  27
# 14  29  26
# 15  21  21
# 16  35  25
# 17  47  31
# 18  54  37
# 19  53  40
# 20  44  48
# 21  24  27
# 22  28  25
# 23  30  32
# 24  38  34
# 25  28  26
# 26  21  20
# 27  14  19
# 28  14  14
# 29  23  17
# 30  16  14

# %%
df[:4]
# Out:
#            날짜  서울  부산  대구  인천  광주    대전  울산  ...  충북  충남  전북  전남  경북  경남    제주  세종
# 0  2020-08-01  15  23  26  17  16  17.0  26  ...  20  19  16  21  20  24  28.0  17
# 1  2020-08-02  12  41  28  15  18  13.0  33  ...  14  17  17  31  25  36  38.0  14
# 2  2020-08-03  15  44  32  19  29  18.0  36  ...  18  23  26  38  28  40  42.0  18
# 3  2020-08-04  38  65  44  47  38  25.0  54  ...  23  38  34  52  38  57  54.0  26
#
# [4 rows x 18 columns]

# %%
df.loc[:4, :]
# Out:
#            날짜  서울  부산  대구  인천  광주    대전  울산  ...  충북  충남  전북  전남  경북  경남    제주  세종
# 0  2020-08-01  15  23  26  17  16  17.0  26  ...  20  19  16  21  20  24  28.0  17
# 1  2020-08-02  12  41  28  15  18  13.0  33  ...  14  17  17  31  25  36  38.0  14
# 2  2020-08-03  15  44  32  19  29  18.0  36  ...  18  23  26  38  28  40  42.0  18
# 3  2020-08-04  38  65  44  47  38  25.0  54  ...  23  38  34  52  38  57  54.0  26
# 4  2020-08-05  35  34  41  36  28  28.0  33  ...  23  32  28  33  39  34  32.0  26
#
# [5 rows x 18 columns]

# %% [markdown]
# #### **.iloc : 순서번호로 추출**

# %%
df.iloc[:2]
# Out:
#            날짜  서울  부산  대구  인천  광주    대전  울산  ...  충북  충남  전북  전남  경북  경남    제주  세종
# 0  2020-08-01  15  23  26  17  16  17.0  26  ...  20  19  16  21  20  24  28.0  17
# 1  2020-08-02  12  41  28  15  18  13.0  33  ...  14  17  17  31  25  36  38.0  14
#
# [2 rows x 18 columns]

# %%
df.iloc[:2, [0,2,4]]
# Out:
#            날짜  부산  인천
# 0  2020-08-01  23  17
# 1  2020-08-02  41  15

# %% [markdown]
# #### 행열 전환
# + 데이터프레임.T

# %%
dft = df.T

# %%
dft
# Out:
#             0           1           2   ...          28          29          30
# 날짜  2020-08-01  2020-08-02  2020-08-03  ...  2020-08-29  2020-08-30  2020-08-31
# 서울          15          12          15  ...          16          14          10
# 부산          23          41          44  ...          14          23          16
# 대구          26          28          32  ...          14          17          14
# 인천          17          15          19  ...          16          15          11
# 광주          16          18          29  ...           9          12          18
# 대전          17          13          18  ...          10          11           7
# 울산          26          33          36  ...          15          17          15
# 경기          17          12          14  ...          16          16          12
# 강원          17          11          12  ...          15          11          14
# 충북          20          14          18  ...          12          11          12
# ...

# %% [markdown]
# ##해결문제
# ---
# 해결문제) 부산시기온.csv파일을 읽어서 2018년 최고, 최저 기온을 추출하고 통계량을 표시하시오.
#
#
# ---

# %%
dfbusan = pd.read_csv('/content/drive/My Drive/gifted/04/부산시기온.csv',engine='python')
dfbusan
# Out:
#             일시    평균    최고    최저
# 0   2017-01-01   4.1  15.1  -7.7
# 1   2017-02-01   5.5  17.7  -5.7
# 2   2017-03-01   9.0  18.1  -2.3
# 3   2017-04-01  15.0  23.2   5.0
# 4   2017-05-01  19.0  28.2  12.8
# 5   2017-06-01  21.3  30.4  15.4
# 6   2017-07-01  26.1  32.7  21.2
# 7   2017-08-01  27.0  36.2  18.7
# 8   2017-09-01  22.6  29.7  14.5
# 9   2017-10-01  18.1  28.7   7.3
# 10  2017-11-01  11.2  23.6  -1.0
# 11  2017-12-01   3.6  14.5  -6.1
# 12  2018-01-01   1.9  14.0  -9.9
# 13  2018-02-01   3.9  14.7  -9.6
# 14  2018-03-01  10.0  22.3  -0.7
# 15  2018-04-01  14.5  24.3   3.0
# 16  2018-05-01  17.8  26.6   9.8
# 17  2018-06-01  21.5  31.3  15.1
# 18  2018-07-01  26.7  35.4  17.8
# 19  2018-08-01  27.9  36.4  21.2
# 20  2018-09-01  21.9  30.0  14.9
# 21  2018-10-01  16.4  25.6   7.9
# 22  2018-11-01  12.4  22.5   2.7
# 23  2018-12-01   5.7  18.8  -7.1
# 24  2019-01-01   4.5  13.7  -4.4
# 25  2019-02-01   6.6  16.5  -4.2
# 26  2019-03-01  10.5  21.0   0.5
# ...

# %%
dfbusan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   일시      30 non-null     object
#  1   평균      30 non-null     float64
#  2   최고      30 non-null     float64
#  3   최저      30 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 1.1+ KB

# %%
dfbusan = dfbusan.loc[12:23, ['일시','최고','최저']]
dfbusan
# Out:
#             일시    최고    최저
# 12  2018-01-01  14.0  -9.9
# 13  2018-02-01  14.7  -9.6
# 14  2018-03-01  22.3  -0.7
# 15  2018-04-01  24.3   3.0
# 16  2018-05-01  26.6   9.8
# 17  2018-06-01  31.3  15.1
# 18  2018-07-01  35.4  17.8
# 19  2018-08-01  36.4  21.2
# 20  2018-09-01  30.0  14.9
# 21  2018-10-01  25.6   7.9
# 22  2018-11-01  22.5   2.7
# 23  2018-12-01  18.8  -7.1

# %%
dfbusan.describe()
# Out:
#               최고         최저
# count  12.000000  12.000000
# mean   25.158333   5.425000
# std     7.292519  10.782741
# min    14.000000  -9.900000
# 25%    21.425000  -2.300000
# 50%    24.950000   5.450000
# 75%    30.325000  14.950000
# max    36.400000  21.200000

# %% [markdown]
# #### 데이터 유형 확인
# + 데이터프레임.dtypes : 각열의 유형을 알려줌
# + 열시리즈.astype() : 특정 유형으로 변경
#  - .astype(float64) , .astype(float32) , .astype(float16), .astype(int)
#  - .astype(str)
# + pd.to_numeric() : 숫자 유형으로 변경
#   - errors 매개 변수
#   - errors='ignore' : 무시
#  - errors='coerce' : NaN
#
# + pd.to_datetime(열명)
#  - .dt.year : 년도
#  - .dt.month : 월
#  - .dt.day : 일

# %%
dfbusan['일시'] = pd.to_datetime(dfbusan['일시'])

# %%
dfbusan['년도'] = dfbusan['일시'].dt.year

# %%
dfbusan2018 = dfbusan[dfbusan['년도'] == 2018]

# %%
dfbusan2018
# Out:
#            일시    최고    최저    년도
# 12 2018-01-01  14.0  -9.9  2018
# 13 2018-02-01  14.7  -9.6  2018
# 14 2018-03-01  22.3  -0.7  2018
# 15 2018-04-01  24.3   3.0  2018
# 16 2018-05-01  26.6   9.8  2018
# 17 2018-06-01  31.3  15.1  2018
# 18 2018-07-01  35.4  17.8  2018
# 19 2018-08-01  36.4  21.2  2018
# 20 2018-09-01  30.0  14.9  2018
# 21 2018-10-01  25.6   7.9  2018
# 22 2018-11-01  22.5   2.7  2018
# 23 2018-12-01  18.8  -7.1  2018

# %%
dfbusan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 12 to 23
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   일시      12 non-null     datetime64[ns]
#  1   최고      12 non-null     float64
#  2   최저      12 non-null     float64
#  3   년도      12 non-null     int64
# dtypes: datetime64[ns](1), float64(2), int64(1)
# memory usage: 516.0 bytes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 19 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      31 non-null     datetime64[ns]
#  1   서울      31 non-null     int64
#  2   부산      31 non-null     int64
#  3   대구      31 non-null     int64
#  4   인천      31 non-null     int64
#  5   광주      31 non-null     int64
#  6   대전      30 non-null     float64
#  7   울산      31 non-null     int64
#  8   경기      31 non-null     int64
#  9   강원      31 non-null     int64
#  10  충북      31 non-null     int64
#  11  충남      31 non-null     int64
#  12  전북      31 non-null     int64
#  13  전남      31 non-null     int64
#  14  경북      31 non-null     int64
#  15  경남      31 non-null     int64
#  16  제주      30 non-null     float64
#  17  세종      31 non-null     int64
#  18  년도      31 non-null     int64
# dtypes: datetime64[ns](1), float64(2), int64(16)
# memory usage: 4.7 KB

# %%
df['날짜'] = pd.to_datetime(df['날짜'])

# %%
df['년도'] = df['날짜'].dt.year

# %%
df.head()
# Out:
#           날짜  서울  부산  대구  인천  광주    대전  울산  ...  충남  전북  전남  경북  경남    제주  세종    년도
# 0 2020-08-01  15  23  26  17  16  17.0  26  ...  19  16  21  20  24  28.0  17  2020
# 1 2020-08-02  12  41  28  15  18  13.0  33  ...  17  17  31  25  36  38.0  14  2020
# 2 2020-08-03  15  44  32  19  29  18.0  36  ...  23  26  38  28  40  42.0  18  2020
# 3 2020-08-04  38  65  44  47  38  25.0  54  ...  38  34  52  38  57  54.0  26  2020
# 4 2020-08-05  35  34  41  36  28  28.0  33  ...  32  28  33  39  34  32.0  26  2020
#
# [5 rows x 19 columns]

# %%
df.loc[5, '대전'] = 0

# %%
df.loc[5, '대전']
# Out:
# 0.0

# %%
df['대전'] = pd.to_numeric(df['대전'], errors='ignore' )

# %%
df['대전'] = df['대전'].astype(int)

# %%
df.loc[25, '제주'] = 0

# %%
df['제주'] = df['제주'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 19 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      31 non-null     datetime64[ns]
#  1   서울      31 non-null     int64
#  2   부산      31 non-null     int64
#  3   대구      31 non-null     int64
#  4   인천      31 non-null     int64
#  5   광주      31 non-null     int64
#  6   대전      31 non-null     int64
#  7   울산      31 non-null     int64
#  8   경기      31 non-null     int64
#  9   강원      31 non-null     int64
#  10  충북      31 non-null     int64
#  11  충남      31 non-null     int64
#  12  전북      31 non-null     int64
#  13  전남      31 non-null     int64
#  14  경북      31 non-null     int64
#  15  경남      31 non-null     int64
#  16  제주      31 non-null     int64
#  17  세종      31 non-null     int64
#  18  년도      31 non-null     int64
# dtypes: datetime64[ns](1), int64(18)
# memory usage: 4.7 KB

# %%
df.dtypes
# Out:
# 날짜    datetime64[ns]
# 서울             int64
# 부산             int64
# 대구             int64
# 인천             int64
# 광주             int64
# 대전             int64
# 울산             int64
# 경기             int64
# 강원             int64
# 충북             int64
# 충남             int64
# 전북             int64
# 전남             int64
# 경북             int64
# 경남             int64
# 제주             int64
# 세종             int64
# 년도             int64
# dtype: object

# %%
df['날짜'] = pd.to_datetime(df['날짜'] )
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 19 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      31 non-null     datetime64[ns]
#  1   서울      31 non-null     int64
#  2   부산      31 non-null     int64
#  3   대구      31 non-null     int64
#  4   인천      31 non-null     int64
#  5   광주      31 non-null     int64
#  6   대전      31 non-null     int64
#  7   울산      31 non-null     int64
#  8   경기      31 non-null     int64
#  9   강원      31 non-null     int64
#  10  충북      31 non-null     int64
#  11  충남      31 non-null     int64
#  12  전북      31 non-null     int64
#  13  전남      31 non-null     int64
#  14  경북      31 non-null     int64
#  15  경남      31 non-null     int64
#  16  제주      31 non-null     int64
#  17  세종      31 non-null     int64
#  18  년도      31 non-null     int64
# dtypes: datetime64[ns](1), int64(18)
# memory usage: 4.7 KB

# %% [markdown]
# ## 데이터프레임 인덱스 설정
# + set_index : 기존의 행 인덱스를 제거하고 데이터 열 중 하나를 인덱스로 설정
# + reset_index : 기존의 행 인덱스를 제거하고 인덱스를 데이터 열로 추가

# %%
df2 = df

# %%
df2 = df2.set_index('날짜')
df2.head()
# Out:
#             서울  부산  대구  인천  광주  대전  울산  경기  ...  충남  전북  전남  경북  경남  제주  세종    년도
# 날짜                                          ...
# 2020-08-01  15  23  26  17  16  17  26  17  ...  19  16  21  20  24  28  17  2020
# 2020-08-02  12  41  28  15  18  13  33  12  ...  17  17  31  25  36  38  14  2020
# 2020-08-03  15  44  32  19  29  18  36  14  ...  23  26  38  28  40  42  18  2020
# 2020-08-04  38  65  44  47  38  25  54  35  ...  38  34  52  38  57  54  26  2020
# 2020-08-05  35  34  41  36  28  28  33  33  ...  32  28  33  39  34  32  26  2020
#
# [5 rows x 18 columns]

# %%
df2 = df2.reset_index()
df2.head()
# Out:
#           날짜  서울  부산  대구  인천  광주  대전  울산  ...  충남  전북  전남  경북  경남  제주  세종    년도
# 0 2020-08-01  15  23  26  17  16  17  26  ...  19  16  21  20  24  28  17  2020
# 1 2020-08-02  12  41  28  15  18  13  33  ...  17  17  31  25  36  38  14  2020
# 2 2020-08-03  15  44  32  19  29  18  36  ...  23  26  38  28  40  42  18  2020
# 3 2020-08-04  38  65  44  47  38  25  54  ...  38  34  52  38  57  54  26  2020
# 4 2020-08-05  35  34  41  36  28  28  33  ...  32  28  33  39  34  32  26  2020
#
# [5 rows x 19 columns]

# %%
#열추가
df2['년도'] = df2['날짜'].dt.year
df2.head()
# Out:
#           날짜  서울  부산  대구  인천  광주  대전  울산  ...  충남  전북  전남  경북  경남  제주  세종    년도
# 0 2020-08-01  15  23  26  17  16  17  26  ...  19  16  21  20  24  28  17  2020
# 1 2020-08-02  12  41  28  15  18  13  33  ...  17  17  31  25  36  38  14  2020
# 2 2020-08-03  15  44  32  19  29  18  36  ...  23  26  38  28  40  42  18  2020
# 3 2020-08-04  38  65  44  47  38  25  54  ...  38  34  52  38  57  54  26  2020
# 4 2020-08-05  35  34  41  36  28  28  33  ...  32  28  33  39  34  32  26  2020
#
# [5 rows x 19 columns]

# %%
df2 = df2.set_index('날짜')
df2.head()
# Out:
#             서울  부산  대구  인천  광주  대전  울산  경기  ...  충남  전북  전남  경북  경남  제주  세종    년도
# 날짜                                          ...
# 2020-08-01  15  23  26  17  16  17  26  17  ...  19  16  21  20  24  28  17  2020
# 2020-08-02  12  41  28  15  18  13  33  12  ...  17  17  31  25  36  38  14  2020
# 2020-08-03  15  44  32  19  29  18  36  14  ...  23  26  38  28  40  42  18  2020
# 2020-08-04  38  65  44  47  38  25  54  35  ...  38  34  52  38  57  54  26  2020
# 2020-08-05  35  34  41  36  28  28  33  33  ...  32  28  33  39  34  32  26  2020
#
# [5 rows x 18 columns]

# %%
#행 추가
df2.loc['평균'] = df.mean(axis=0)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.

# %%
df2
# Out:
#                             서울        부산  ...         세종      년도
# 날짜                                        ...
# 2020-08-01 00:00:00  15.000000  23.00000  ...  17.000000  2020.0
# 2020-08-02 00:00:00  12.000000  41.00000  ...  14.000000  2020.0
# 2020-08-03 00:00:00  15.000000  44.00000  ...  18.000000  2020.0
# 2020-08-04 00:00:00  38.000000  65.00000  ...  26.000000  2020.0
# 2020-08-05 00:00:00  35.000000  34.00000  ...  26.000000  2020.0
# 2020-08-06 00:00:00  16.000000  43.00000  ...  14.000000  2020.0
# 2020-08-07 00:00:00  27.000000  48.00000  ...  15.000000  2020.0
# 2020-08-08 00:00:00  14.000000  16.00000  ...   6.000000  2020.0
# 2020-08-09 00:00:00  10.000000  17.00000  ...  10.000000  2020.0
# 2020-08-10 00:00:00  13.000000  15.00000  ...  10.000000  2020.0
# 2020-08-11 00:00:00  11.000000  23.00000  ...  10.000000  2020.0
# 2020-08-12 00:00:00  23.000000  20.00000  ...  18.000000  2020.0
# 2020-08-13 00:00:00  26.000000  23.00000  ...  21.000000  2020.0
# ...

# %% [markdown]
# #### 행열 삭제
# + .drop(행인덱스, axis=0)
# + .drop(열인덱스, axis=1)

# %%
df2 = df2.drop('평균', axis=0)
df2 = df2.drop('년도', axis=1)
df2
# Out:
#                        서울    부산    대구    인천    광주  ...    전남    경북    경남    제주    세종
# 날짜                                                 ...
# 2020-08-01 00:00:00  15.0  23.0  26.0  17.0  16.0  ...  21.0  20.0  24.0  28.0  17.0
# 2020-08-02 00:00:00  12.0  41.0  28.0  15.0  18.0  ...  31.0  25.0  36.0  38.0  14.0
# 2020-08-03 00:00:00  15.0  44.0  32.0  19.0  29.0  ...  38.0  28.0  40.0  42.0  18.0
# 2020-08-04 00:00:00  38.0  65.0  44.0  47.0  38.0  ...  52.0  38.0  57.0  54.0  26.0
# 2020-08-05 00:00:00  35.0  34.0  41.0  36.0  28.0  ...  33.0  39.0  34.0  32.0  26.0
# 2020-08-06 00:00:00  16.0  43.0  23.0  16.0  20.0  ...  25.0  22.0  32.0  42.0  14.0
# 2020-08-07 00:00:00  27.0  48.0  18.0  22.0  16.0  ...  46.0  17.0  42.0  62.0  15.0
# 2020-08-08 00:00:00  14.0  16.0   7.0  13.0  12.0  ...  21.0   8.0  15.0  24.0   6.0
# 2020-08-09 00:00:00  10.0  17.0  11.0  11.0  11.0  ...  17.0  14.0  15.0  17.0  10.0
# ...

# %% [markdown]
# #### 정렬하기
# + .sort_index()
#  - 인덱스(index)를 기준으로 정렬
# + .sort_values()
#  - 컬럼의 값을 기준으로 데이터를 정렬
#  - 옵션 : by=컬럼 , ascending=False

# %%
df2 = df2.sort_values(by='부산')
df2
# Out:
#                        서울    부산    대구    인천    광주  ...    전남    경북    경남    제주    세종
# 날짜                                                 ...
# 2020-08-29 00:00:00  16.0  14.0  14.0  16.0   9.0  ...  14.0  15.0  17.0  17.0  10.0
# 2020-08-28 00:00:00  23.0  14.0  19.0  22.0  13.0  ...  17.0  19.0  16.0  21.0  17.0
# 2020-08-10 00:00:00  13.0  15.0   9.0  13.0   8.0  ...  13.0   9.0  12.0  19.0  10.0
# 2020-08-31 00:00:00  10.0  16.0  14.0  11.0  18.0  ...  19.0  15.0  19.0  22.0  10.0
# 2020-08-08 00:00:00  14.0  16.0   7.0  13.0  12.0  ...  21.0   8.0  15.0  24.0   6.0
# 2020-08-09 00:00:00  10.0  17.0  11.0  11.0  11.0  ...  17.0  14.0  15.0  17.0  10.0
# 2020-08-12 00:00:00  23.0  20.0  22.0  26.0  17.0  ...  21.0  17.0  21.0  24.0  18.0
# 2020-08-27 00:00:00  21.0  21.0  20.0  23.0  24.0  ...  30.0  19.0  23.0  26.0  19.0
# 2020-08-16 00:00:00  23.0  21.0  21.0  22.0  17.0  ...  19.0  22.0  21.0  20.0  17.0
# ...

# %%
df2 = df2.sort_index()
df2
# Out:
#                        서울    부산    대구    인천    광주  ...    전남    경북    경남    제주    세종
# 날짜                                                 ...
# 2020-08-01 00:00:00  15.0  23.0  26.0  17.0  16.0  ...  21.0  20.0  24.0  28.0  17.0
# 2020-08-02 00:00:00  12.0  41.0  28.0  15.0  18.0  ...  31.0  25.0  36.0  38.0  14.0
# 2020-08-03 00:00:00  15.0  44.0  32.0  19.0  29.0  ...  38.0  28.0  40.0  42.0  18.0
# 2020-08-04 00:00:00  38.0  65.0  44.0  47.0  38.0  ...  52.0  38.0  57.0  54.0  26.0
# 2020-08-05 00:00:00  35.0  34.0  41.0  36.0  28.0  ...  33.0  39.0  34.0  32.0  26.0
# 2020-08-06 00:00:00  16.0  43.0  23.0  16.0  20.0  ...  25.0  22.0  32.0  42.0  14.0
# 2020-08-07 00:00:00  27.0  48.0  18.0  22.0  16.0  ...  46.0  17.0  42.0  62.0  15.0
# 2020-08-08 00:00:00  14.0  16.0   7.0  13.0  12.0  ...  21.0   8.0  15.0  24.0   6.0
# 2020-08-09 00:00:00  10.0  17.0  11.0  11.0  11.0  ...  17.0  14.0  15.0  17.0  10.0
# ...

# %% [markdown]
# ## 해결문제
# ---
# 해결문제)
#  mv1.csv 파일을 읽어서
#  + 2019년 자료를 추출하여 평점 평균을 구하시오.
#  + 1위부터 20위까지 평점 그래프를 그리시오.
#
# ---

# %%
dfmv = pd.read_csv('/content/drive/My Drive/gifted/04/mv1.csv',names=['영화코드', '순위', '링크', '영화명', '평점', '일자'], header=None)
dfmv.head()
# Out:
#      영화코드  순위                             링크          영화명   평점           일자
# 0  119859   1   /moviedb/main?movieId=119859         극한직업  7.4   2019.01.23
# 1   93252   2    /moviedb/main?movieId=93252   어벤져스: 엔드게임  7.8   2019.04.24
# 2   93004   3    /moviedb/main?movieId=93004       겨울왕국 2  7.4   2019.11.21
# 3  115601   4   /moviedb/main?movieId=115601          알라딘  8.4   2019.05.23
# 4  111292   5   /moviedb/main?movieId=111292          기생충  7.9   2019.05.30

# %%
df = dfmv[['일자','영화명','순위', '평점']]
df.head()
# Out:
#             일자          영화명  순위   평점
# 0   2019.01.23         극한직업   1  7.4
# 1   2019.04.24   어벤져스: 엔드게임   2  7.8
# 2   2019.11.21       겨울왕국 2   3  7.4
# 3   2019.05.23          알라딘   4  8.4
# 4   2019.05.30          기생충   5  7.9

# %%
df['일자'] = pd.to_datetime(df['일자'])
df.dtypes
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 일자     datetime64[ns]
# 영화명            object
# 순위              int64
# 평점            float64
# dtype: object

# %%
df2019 = df[df['일자'].dt.year == 2019]
df2019
# Out:
#            일자                 영화명  순위   평점
# 0  2019-01-23                극한직업   1  7.4
# 1  2019-04-24          어벤져스: 엔드게임   2  7.8
# 2  2019-11-21              겨울왕국 2   3  7.4
# 3  2019-05-23                 알라딘   4  8.4
# 4  2019-05-30                 기생충   5  7.9
# 5  2019-07-31                 엑시트   6  7.7
# 6  2019-07-02       스파이더맨: 파 프롬 홈   7  6.5
# 7  2019-12-19                 백두산   8  6.5
# 8  2019-03-06               캡틴 마블   9  6.3
# 9  2019-10-02                  조커  10  7.7
# 10 2019-08-07              봉오동 전투  11  8.8
# 11 2019-07-17               라이온 킹  12  7.4
# 12 2019-09-11        나쁜 녀석들: 더 무비  13  6.3
# 13 2019-10-23            82년생 김지영  14  6.7
# 14 2019-08-14        분노의 질주: 홉스&쇼  15  7.0
# 15 2019-06-20            토이 스토리 4  16  8.6
# 16 2019-03-20                   돈  17  6.7
# 17 2019-05-15                 악인전  18  7.4
# 18 2019-10-02           가장 보통의 연애  19  7.4
# 19 2019-01-09                 말모이  20  9.1
# 20 2019-02-13                  증인  21  9.3
# ...

# %%
avg = df2019['평점'].mean()
print(f'2019년 평점 평균 : {avg:0.2f}')
# Out:
# 2019년 평점 평균 : 7.48

# %%
df2019_20 = df2019[df2019['순위'] <= 20]
df2019_20 = df2019_20[['영화명', '평점']]
df2019_20
# Out:
#                영화명   평점
# 0             극한직업  7.4
# 1       어벤져스: 엔드게임  7.8
# 2           겨울왕국 2  7.4
# 3              알라딘  8.4
# 4              기생충  7.9
# 5              엑시트  7.7
# 6    스파이더맨: 파 프롬 홈  6.5
# 7              백두산  6.5
# 8            캡틴 마블  6.3
# 9               조커  7.7
# 10          봉오동 전투  8.8
# 11           라이온 킹  7.4
# 12    나쁜 녀석들: 더 무비  6.3
# 13        82년생 김지영  6.7
# 14    분노의 질주: 홉스&쇼  7.0
# 15        토이 스토리 4  8.6
# 16               돈  6.7
# 17             악인전  7.4
# 18       가장 보통의 연애  7.4
# 19             말모이  9.1

# %%
df2019_20.plot(figsize=(15,5), marker='o')
plt.xticks( df2019_20.index, list(df2019_20['영화명']), rotation=90)
plt.show()
