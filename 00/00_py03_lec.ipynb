# %% [markdown]
# # 모듈(Module)
# + 함수나 변수 또는 클래스 들을 모아 놓은 파일
# + 다른 파이썬 프로그램에서 불러와 사용할 수 있게끔 만들어진 파이썬 파일
#
# ### 모듈 불러오기
# + import 모듈이름
#  - 모듈 이름은  .py 확장자를 제거한 파일이름
# + import 모듈이름 as 별명
#  - 모듈 이름을 별명으로 사용
# + from 모듈이름 import 모듈함수
#  - 모듈 이름을 붙이지 않고 바로 해당 모듈의 함수
#
# ### 대표적 모듈
# + matplotlib.pyplot : 시각화 모듈
# + numpy : 수치해석 모듈
# + pandas : 데이터 분석 모듈
# + requests : HTTP 요청/응답 모듈

# %% [markdown]
# # 데이터 시각화 : matplotlib.pyplot

# %% [markdown]
# ### matplotlib 한글 처리 (colab 환경)

# %%
import matplotlib.font_manager as fm

# 설치된 폰트 출력
font_list = [font.name for font in fm.fontManager.ttflist]
font_list
# Out:
# ['STIXSizeFourSym',
#  'STIXNonUnicode',
#  'DejaVu Serif',
#  'STIXGeneral',
#  'STIXSizeTwoSym',
#  'DejaVu Sans',
#  'STIXSizeFourSym',
#  'cmb10',
#  'DejaVu Sans Mono',
#  'cmr10',
#  'DejaVu Sans',
#  'DejaVu Sans Mono',
#  'STIXSizeFiveSym',
#  'DejaVu Serif',
#  'DejaVu Serif',
#  'STIXSizeTwoSym',
#  'DejaVu Sans Display',
#  'STIXNonUnicode',
#  'STIXSizeOneSym',
#  'STIXSizeOneSym',
#  'STIXSizeThreeSym',
#  'cmtt10',
#  'DejaVu Sans',
#  'STIXGeneral',
#  'STIXNonUnicode',
#  'cmex10',
#  'cmmi10',
#  'STIXNonUnicode',
#  'DejaVu Sans Mono',
#  'STIXGeneral',
#  'cmsy10',
#  'DejaVu Serif',
#  'DejaVu Sans Mono',
#  'DejaVu Sans',
#  'DejaVu Serif Display',
#  'cmss10',
#  'STIXSizeThreeSym',
#  'STIXGeneral',
#  'Gadugi',
#  'Copperplate Gothic Bold',
#  'Franklin Gothic Demi',
#  'Lucida Fax',
#  'Gill Sans MT Ext Condensed Bold',
#  'Microsoft YaHei',
#  'Rage Italic',
#  'Magneto',
#  'Nirmala UI',
#  'Leelawadee',
#  'Old English Text MT',
#  'Bodoni MT',
#  'Segoe Print',
#  'Arial',
#  'Bodoni MT',
#  'Lucida Sans Typewriter',
#  'Franklin Gothic Medium',
#  'Informal Roman',
#  'Tw Cen MT Condensed Extra Bold',
#  'Jokerman',
#  'Comic Sans MS',
#  'Batang',
#  'HCR Dotum',
#  'Bell MT',
#  'Californian FB',
#  'Segoe MDL2 Assets',
#  'HYPost-Light',
#  'Corbel',
#  'HYMyeongJo-Extra',
#  'Perpetua',
#  'Agency FB',
#  'HYPost-Medium',
#  'Centaur',
#  'Tw Cen MT',
#  'Lucida Bright',
#  'Candara',
#  'Sylfaen',
#  'Lucida Sans',
#  'Gill Sans MT',
#  'Vivaldi',
#  'Tw Cen MT',
#  'Pristina',
#  'Century Gothic',
#  'Bodoni MT',
#  'New Gulim',
#  'Arial',
#  'Century Gothic',
#  'HCR Batang',
#  'KBIZmjo R',
#  'Bodoni MT',
#  'Segoe UI Historic',
#  'Candara',
#  'Segoe UI',
#  'Comic Sans MS',
#  'Chiller',
#  'Microsoft JhengHei',
#  'Rockwell Extra Bold',
#  'Kunstler Script',
#  'Microsoft Uighur',
#  'Calisto MT',
#  'Georgia',
#  'Candara',
#  'Garamond',
#  'Onyx',
#  'MT Extra',
#  'Nirmala UI',
#  'Leelawadee UI',
#  'HYGothic-Medium',
#  'Colonna MT',
#  'Lucida Fax',
#  'Cambria',
#  'Century Schoolbook',
#  'Yu Gothic',
#  'Palatino Linotype',
#  'NewJumja',
#  'Ink Free',
#  'Century Schoolbook',
#  'Tw Cen MT Condensed',
#  'Forte',
#  'Elephant',
#  'Bauhaus 93',
#  'Myanmar Text',
#  'Vladimir Script',
#  'Franklin Gothic Heavy',
#  'KBIZmjo M',
#  'Microsoft PhagsPa',
#  'Calisto MT',
#  'Bell MT',
#  'Comic Sans MS',
#  'Bookshelf Symbol 7',
#  'Bookman Old Style',
#  'Bodoni MT',
#  'Microsoft JhengHei',
#  'Bodoni MT',
#  'Gill Sans MT Condensed',
#  'Gill Sans Ultra Bold Condensed',
#  'Magic R',
#  'SimSun-ExtB',
#  'Malgun Gothic',
#  'Microsoft Yi Baiti',
#  'Calibri',
#  'MJemokBatang',
#  'Georgia',
#  'HCR Batang ExtB',
#  'Gloucester MT Extra Condensed',
#  'Trebuchet MS',
#  'Eras Demi ITC',
#  'Marlett',
#  'Wingdings 2',
#  'Trebuchet MS',
#  'Tempus Sans ITC',
#  'Showcard Gothic',
#  'Gill Sans MT',
#  'Lucida Sans Typewriter',
#  'Tw Cen MT',
#  'Sitka Small',
#  'MJemokGothic',
#  'Mistral',
#  'Perpetua',
#  'Arial',
#  'Niagara Engraved',
#  'Myanmar Text',
#  'Segoe UI',
#  'Verdana',
#  'Goudy Old Style',
#  'Agency FB',
#  'Segoe UI',
#  'Bodoni MT',
#  'Lucida Sans Typewriter',
#  'Lucida Sans',
#  'Segoe UI',
#  'Calibri',
#  'HCR Dotum',
#  'Segoe UI',
#  'MoeumT R',
#  'Monotype Corsiva',
#  'HYPMokGak-Bold',
#  'Palatino Linotype',
#  'Copperplate Gothic Light',
#  'Constantia',
#  'HYGothic-Extra',
#  'Lucida Bright',
#  'Rockwell',
#  'Gill Sans Ultra Bold',
#  'Segoe UI',
#  'Segoe UI',
#  'Tahoma',
#  'Ravie',
#  'Freestyle Script',
#  'MV Boli',
#  'Stencil',
#  'Arial',
#  'Franklin Gothic Medium',
#  'Lucida Handwriting',
#  'Impact',
#  'Modern No. 20',
#  'Bodoni MT',
#  'High Tower Text',
#  'Bahnschrift',
#  'Tahoma',
#  'Malgun Gothic',
#  'Microsoft New Tai Lue',
#  'HYSinMyeongJo-Medium',
#  'Rockwell',
#  'Californian FB',
#  'HCR Dotum Ext',
#  'Microsoft Sans Serif',
#  'Gill Sans MT',
#  'Calibri',
#  'Yu Gothic',
#  'Cambria',
#  'Candara',
#  'Lucida Bright',
#  'Perpetua Titling MT',
#  'Britannic Bold',
#  'Lucida Sans',
#  'OCR A Extended',
#  'Leelawadee UI',
#  'Segoe UI Symbol',
#  'Microsoft YaHei',
#  'Segoe UI',
#  'Segoe UI',
#  'Arial',
#  'Ebrima',
#  'HyhwpEQ',
#  'Bernard MT Condensed',
#  'Microsoft JhengHei',
#  'Sitka Small',
#  'Rockwell Condensed',
#  'Algerian',
#  'Courier New',
#  'Book Antiqua',
#  'Bodoni MT',
#  'Courier New',
#  'Papyrus',
#  'Century',
#  'Perpetua Titling MT',
#  'MS Reference Specialty',
#  'Sitka Small',
#  'MSugiJeong',
#  'Microsoft Himalaya',
#  'Berlin Sans FB Demi',
#  'Segoe Script',
#  'Microsoft PhagsPa',
#  'Century Schoolbook',
#  'Franklin Gothic Demi',
#  'Castellar',
#  'Times New Roman',
#  'HCR Batang ExtB',
#  'Lucida Calligraphy',
#  'Franklin Gothic Demi Cond',
#  'Bodoni MT',
#  'Poor Richard',
#  'Microsoft Uighur',
#  'KBIZgo R',
#  'Candara',
#  'Book Antiqua',
#  'Times New Roman',
#  'Lucida Sans Unicode',
#  'Cambria',
#  'Eras Medium ITC',
#  'Palatino Linotype',
#  'Bookman Old Style',
#  'Microsoft Tai Le',
#  'Californian FB',
#  'Calisto MT',
#  'MHunmin',
#  'Gadugi',
#  'Lucida Fax',
#  'Gigi',
#  'MDotum',
#  'Sitka Small',
#  'Trebuchet MS',
#  'Book Antiqua',
#  'Tw Cen MT Condensed',
#  'Times New Roman',
#  'Curlz MT',
#  'HYShortSamul-Medium',
#  'MGungHeulim',
#  'Segoe Print',
#  'Snap ITC',
#  'MSugiHeulim',
#  'Wide Latin',
#  'Juice ITC',
#  'Cooper Black',
#  'Corbel',
#  'HoloLens MDL2 Assets',
#  'Rockwell',
#  'Maiandra GD',
#  'MS Gothic',
#  'Lucida Sans',
#  'Verdana',
#  'Arial Rounded MT Bold',
#  'Imprint MT Shadow',
#  'Bodoni MT',
#  'MGungJeong',
#  'Microsoft YaHei',
#  'Consolas',
#  'Constantia',
#  'Javanese Text',
#  'Corbel',
#  'Baskerville Old Face',
#  'Segoe UI',
#  'Calibri',
#  'Lucida Console',
#  'Segoe UI',
#  'Calibri',
#  'Consolas',
#  'Perpetua',
#  'MS Reference Sans Serif',
#  'Playbill',
#  'HCR Batang Ext',
#  'Century Schoolbook',
#  'Mongolian Baiti',
#  'Garamond',
#  'KBIZmjo B',
#  'Wingdings',
#  'Palatino Linotype',
#  'Leelawadee',
#  'Edwardian Script ITC',
#  'Franklin Gothic Heavy',
#  'Verdana',
#  'Lucida Bright',
#  'Bookman Old Style',
#  'Microsoft Tai Le',
#  'HYHeadLine-Medium',
#  'Eras Light ITC',
#  'Arial',
#  'Bell MT',
#  'Niagara Solid',
#  'Corbel',
#  'HYGraphic-Medium',
#  'KBIZgo B',
#  'Headline R',
#  'Gulim',
#  'Kristen ITC',
#  'Georgia',
#  'Malgun Gothic',
#  'MS Outlook',
#  'Rockwell Condensed',
#  'Yet R',
#  'Blackadder ITC',
#  'Felix Titling',
#  'Gabriola',
#  'Constantia',
#  'Trebuchet MS',
#  'Berlin Sans FB',
#  'Franklin Gothic Medium Cond',
#  'Parchment',
#  'Consolas',
#  'Century Gothic',
#  'Corbel',
#  'High Tower Text',
#  'Engravers MT',
#  'Brush Script MT',
#  'Webdings',
#  'Berlin Sans FB',
#  'HYGungSo-Bold',
#  'Segoe UI',
#  'Verdana',
#  'Bradley Hand ITC',
#  'Arial',
#  'Symbol',
#  'Script MT Bold',
#  'Century Gothic',
#  'HCR Batang',
#  'Constantia',
#  'Lucida Sans Typewriter',
#  'Broadway',
#  'Candara',
#  'Georgia',
#  'Arial',
#  'French Script MT',
#  'Courier New',
#  'Book Antiqua',
#  'Corbel',
#  'Elephant',
#  'Consolas',
#  'Haettenschweiler',
#  'Franklin Gothic Book',
#  'Garamond',
#  'Franklin Gothic Book',
#  'Pyunji R',
#  'Viner Hand ITC',
#  'Arial',
#  'Goudy Stout',
#  'Ami R',
#  'Ebrima',
#  'Matura MT Script Capitals',
#  'Yu Gothic',
#  'Yu Gothic',
#  'Comic Sans MS',
#  'Wingdings 3',
#  'Nirmala UI',
#  'Calibri',
#  'Goudy Old Style',
#  'Courier New',
#  'Cambria',
#  'ZWAdobeF',
#  'Tw Cen MT',
#  'Leelawadee UI',
#  'Segoe UI Emoji',
#  'MingLiU-ExtB',
#  'Perpetua',
#  'Lucida Fax',
#  'Microsoft New Tai Lue',
#  'Times New Roman',
#  'MBatang',
#  'Footlight MT Light',
#  'Rockwell',
#  'Gill Sans MT',
#  'Harlow Solid Italic',
#  'Eras Bold ITC',
#  'Bookman Old Style',
#  'KBIZgo M',
#  'Segoe Script',
#  'Harrington',
#  'Goudy Old Style',
#  'Palace Script MT',
#  'SimSun',
#  'Calisto MT']

# %%
# 폰트 적용
plt.rcParams['font.family'] = 'Nanum Brush Script'

# %%
# unicode minus를 사용하지 않기 위한 설정 (minus 깨짐현상 방지)
plt.rcParams['axes.unicode_minus'] = False
# Out:
# fonts-nanum is already the newest version (20170925-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.

# %%
#시각화 모듈
import matplotlib.pyplot as plt

# %% [markdown]
# ### #시각화 모듈

# %%
#부산 3월 기온
temp = [10.8, 8.5, 8.7, 7.9, 5.1, 
        8.1, 8.2, 10.4, 11, 9.9, 
        7.8, 9.5, 11.6, 8.2, 7.7, 
        6.6, 11.1, 12.2, 12.6, 10.4, 
        13.7, 14.1, 12.6, 11.5, 13, 
        14.5, 13.7, 9.4, 10.4, 11.6, 12.9]

# %%
plt.title('3월 기온') 
plt.plot(temp)
plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 50900 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 50728 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 50900 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 50728 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
#그래프 제목 달기
plt.title('3월 기온') 

plt.plot(temp)
plt.show()

# %% [markdown]
# ## **선 옵션**
# + **색상**
#  - b(파란색), g(초록색), r(빨간색), c(청록색), y(노란색), k(검은색), w(흰색)
# + **마커**
#  - o(원), v(역삼각형), ^(삼각형), s(네모), +(플러스), .(점)
# + **선스타일**
#  - \-(solid line), --(dashed line ), -. (dash-dot line), : (dotted line )

# %%
# 선옵션
plt.plot(temp, 'g+--')
plt.show()

# %%
#그래프 제목 달기
plt.title('3월 기온') 
plt.xlabel('날짜')
plt.ylabel('기온')

plt.plot(temp, 'go--')
plt.show()

# %% [markdown]
# ## **그래프 크기 조절**
# + plt.figure()
#  - figsize를 이용하여 가로, 세로 길이 조절 가능 (inch 단위)

# %%
#그래프 크기 조절: 가로 세로를 튜플로 
plt.figure(figsize=(10,6))

plt.title('3월 기온') 
plt.xlabel('날짜')
plt.ylabel('기온')

plt.plot(temp, 'go--')
plt.show()

# %% [markdown]
# # 그리드 (grid)
# + grid() 함수의 첫번째 파라미터를 True로 설정하면 그래프에 그리드 (grid)가 표시
# + alpha:  그리드의 투명도를 설정
#  - 0으로 설정하면 투명하게, 1은 불투명하게 표시
# + linestyle : 선의 스타일을 대쉬 (Dashed)로 설정
#
#
# # 수평 / 수직선 그리기
# + plt.axvline(x, color)
#  - 축을 가로지르는 세로 선 생성
# + plt.axhline(y, color)
#  - 축을 가로지르는 가로 선 생성
#
# # 글자 쓰기
# + plt.text(x, y, s, fontsize)
#  - 원하는 위치에 텍스트 생성

# %%
#그래프 크기 조절: 가로 세로를 튜플로 
plt.figure(figsize=(10,6))
#plt.rcParams['axes.grid'] = FALSE


plt.title('3월 기온') 
plt.xlabel('날짜')
plt.ylabel('기온')

plt.plot(temp, 'go--', label='기본')
plt.grid(True, color='gray', alpha=0.5, linestyle='--')
plt.axhline(y=10, color='r', linewidth=1)
plt.plot(temp, 'b-', drawstyle='steps-post', label='계단식')
plt.legend()
plt.show()

# %%
#그래프 겹쳐 그리기
plt.figure(figsize=(10,6))
plt.plot(temp, 'g--', label='기본')
plt.plot(temp, 'b-', drawstyle='steps-post', label='계단식')
plt.legend(loc='best')
plt.show()

# %%
#여러 그래프 그리기
#그래프 그리기
x = list(range(1,32))
plt.figure(figsize=(10,6))
plt.rcParams['axes.grid'] = False

plt.subplot(2,2,1)
plt.plot(x,temp, 'go--')
plt.title('기본그래프')

plt.subplot(2,2,2)
plt.scatter(x, temp)
plt.title('산포도그래프')

plt.subplot(2,2,3)
plt.bar(x, temp)
plt.title('막대그래프')
 
plt.subplot(2,2,4)
plt.barh(x,temp)
plt.title('막대그래프')
# Out:
# Text(0.5, 1.0, '막대그래프')

# %%
#여러 그래프 그리기 방법2

fig = plt.figure(figsize=(10,6)) 
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)

ax1.plot(temp, 'go--')
ax1.set_title('3월 기온1') 

ax2.plot(temp, 'bx')
ax2.set_title('3월 기온2') 

ax3.plot(temp, 'r+-.')
ax3.set_xlabel('일자')
# Out:
# Text(0.5, 0, '일자')

# %%
#혼합그래프
avg = [4.5,6.6,10.5,13.4,19.3,21.1,24.3,27,23.1,18.6,13,7]
min = [-4.4,-4.2,0.5,2.1,11,15.5,19.8,20.3,15.8,10.4,2,-2.8]
max = [13.7,16.5,21,23.4,30.1,29.7,30.9,35,30.5,28.8,24,16.6]


x = list(range(1, len(avg)+1))

plt.figure(figsize=(10,6))
#plt.rcParams['axes.unicode_minus'] = False  


plt.plot(x,min, 'g--', label='최소')
plt.plot(x,max, 'r-', label='최대')
plt.bar(x,avg, label='평균')

plt.legend()
plt.title('2019년 기온변화')
plt.xlabel('월')

#그래프 보기
plt.show()

# %% [markdown]
# # 자료 만들기
# 다음 사이트에서 지역별 미세먼지(PM10) 현황 자료를 이용하여 지역별 일평균과 최고, 최저값의 그래프를 그리시오.
#
# *   [에어코리아 사이트 ](https://www.airkorea.or.kr/web/sidoQualityCompare?itemCode=10007&pMENU_NO=101)
#
#
# ![%EA%B7%B8%EB%9E%98%ED%94%84.PNG](attachment:%EA%B7%B8%EB%9E%98%ED%94%84.PNG)

# %% [markdown]
# ---
#
#
# ## 해결문제) 다음은 시도별 대기정보이다.
#
# https://www.airkorea.or.kr/web/sidoQualityCompare?itemCode=10008&pMENU_NO=102
#
# 시도별 대기정보는 미세먼지(PM10), 오존(O3), 일산화탄소(CO)의 정보가 순서대로 주어진다.
# 시도별 대기정보를 그래프로 표시하시오.
#
# ---
#
# ![%EA%B7%B8%EB%9E%98%ED%94%841.PNG](attachment:%EA%B7%B8%EB%9E%98%ED%94%841.PNG)

# %%
data = {'서울':[81,0.052,0.4] ,
        '부산':[54,0.072,0.4],
        '대구':[55,0.06,0.4],
        '인천':[52,0.06,0.5],
        '광주':[61,0.064,0.5],
        '대전':[71,0.064,0.4],
        '울산':[60,0.068,0.4],
        '경기':[64,0.06,0.4],
        '강원':[62,0.062,0.4],
        '충북':[59,0.067,0.4],
        '충남':[65,0.063,0.4],
        '전북':[65,0.068,0.4],
        '전남':[51,0.062,0.4],
        '세종':[69,0.06,0.5],
        '경북':[57,0.066,0.4],
        '경남':[49,0.074,0.4],
        '제주':[66,0.076,0.3]}
